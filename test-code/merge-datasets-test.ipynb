# %% [markdown]
# # Merge Observational Data across Datasets

# %% [markdown]
# ## Import and read VKEB

# %%
import pandas as pd
import matplotlib.pyplot as plt
from astroquery.mast import Mast, Observations
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive
import lightkurve as lk

# %matplotlib inline

# plt.rcParams.update({
#     "figure.dpi": 300,
#     "savefig.dpi": 300
# })
# Out:
# /Users/wayfinder/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/lightkurve/prf/__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
keb = pd.read_csv(r'../data/kepler-eclipsing-binary-catalog.csv')
keb = keb.drop(columns='Unnamed: 11')
keb.columns
# Out:
# Index(['KIC', 'period', 'period_err', 'bjd0', 'bjd0_err', 'morph', 'GLon',
#        'GLat', 'kmag', 'Teff', 'SC'],
#       dtype='str')

# %%
keb
# Out:
#            KIC       period  period_err          bjd0  bjd0_err  morph  \
# 0      3863594     0.053268         0.0  55000.000000  0.004327   0.79
# 1     10417986     0.073731         0.0  55000.027476  0.004231   0.99
# 2      8912468     0.094838         0.0  54953.576945  0.005326   0.98
# 3      8758716     0.107205         0.0  54953.672989  0.006197   1.00
# 4     10855535     0.112782         0.0  54964.629315  0.006374   0.99
# ...        ...          ...         ...           ...       ...    ...
# 2915   9408440   989.985000        -1.0  55346.365980  0.096130   0.00
# 2916   8054233  1058.000000        -1.0  54751.806288  0.968052   0.03
# 2917   7672940  1064.270000        -1.0  54977.092960  0.089646   0.00
# 2918  11961695  1082.815000        -1.0  54871.395674  0.211754   0.02
# 2919   4360072  1087.300000        -1.0  55165.611684  1.147790   0.05
#
#          GLon     GLat    kmag    Teff     SC
# 0     -1.0000  -1.0000  -1.000    -1.0  False
# 1     81.0390  11.0820   9.128    -1.0   True
# 2     80.1095   7.8882  11.751  6194.0  False
# 3     77.7478  11.6565  13.531    -1.0  False
# 4     79.3949  15.9212  13.870  7555.0  False
# ...       ...      ...     ...     ...    ...
# 2915  78.5607  12.2615  13.199  5688.0  False
# 2916  78.6142   7.7321  11.783  4733.0  False
# 2917  74.5296  14.6136  12.328    -1.0  False
# 2918  81.8628  15.9404  13.718  5768.0  False
# 2919  71.5008  11.7046  11.159  4950.0  False
#
# [2920 rows x 11 columns]

# %%
keb.loc[0]
# Out:
# KIC            3863594
# period        0.053268
# period_err         0.0
# bjd0           55000.0
# bjd0_err      0.004327
# morph             0.79
# GLon              -1.0
# GLat              -1.0
# kmag              -1.0
# Teff              -1.0
# SC               False
# Name: 0, dtype: object

# %% [markdown]
# ### Sample querying with `MAST` and the `NasaExoplanetArchive` modules

# %%
keplerObs = Observations.query_criteria(target_name='kplr299096355', obs_collection='Kepler')
keplerObs
# Out:
# WARNING: NoResultsWarning: Query returned no results. [astroquery.mast.discovery_portal]
# <Table masked=True length=0>
# intentType obs_collection provenance_name ...  srcDen obsid objID
#    str1         str1            str1      ... float64  str1  str1
# ---------- -------------- --------------- ... ------- ----- -----

# %%
tbl = NasaExoplanetArchive.query_criteria(
        table="cumulative", 
        select="*",
        where="kepid = 11446443"
    )

tbl
# Out:
# <QTable masked=True length=1>
#  kepid   kepoi_name kepler_name ... koi_fittype koi_score      sky_coord
#                                 ...                             deg,deg
#  int32      str9       str10    ...     str7     float64        SkyCoord
# -------- ---------- ----------- ... ----------- --------- -------------------
# 11446443  K00001.01  Kepler-1 b ...     LS+MCMC     0.811 286.80847,49.316399

# %%
NasaExoplanetArchive.query_object("Kepler-16 b")
# Out:
# <QTable masked=True length=2>
#   pl_name   pl_letter  hostname ... sy_kmagerr2       sky_coord
#                                 ...     mag            deg,deg
#    str11       str1      str9   ...   float64          SkyCoord
# ----------- --------- --------- ... ----------- ---------------------
# Kepler-16 b         b Kepler-16 ...      -0.022 289.0758307,51.757229
# Kepler-16 b         b Kepler-16 ...      -0.022 289.0758307,51.757229

# %% [markdown]
# ## Common records between MAST and VKEB

# %%
keb.head()
# Out:
#         KIC    period  period_err          bjd0  bjd0_err  morph     GLon  \
# 0   3863594  0.053268         0.0  55000.000000  0.004327   0.79  -1.0000
# 1  10417986  0.073731         0.0  55000.027476  0.004231   0.99  81.0390
# 2   8912468  0.094838         0.0  54953.576945  0.005326   0.98  80.1095
# 3   8758716  0.107205         0.0  54953.672989  0.006197   1.00  77.7478
# 4  10855535  0.112782         0.0  54964.629315  0.006374   0.99  79.3949
#
#       GLat    kmag    Teff     SC
# 0  -1.0000  -1.000    -1.0  False
# 1  11.0820   9.128    -1.0   True
# 2   7.8882  11.751  6194.0  False
# 3  11.6565  13.531    -1.0  False
# 4  15.9212  13.870  7555.0  False

# %%
sampleIndex = 10
sampleKIC = int(keb.loc[sampleIndex]['KIC'])
sampleKIC
# Out:
# 7375612

# %%
MASTSearch = lk.search_lightcurve(
    f"{sampleKIC}",
    mission="Kepler"
)

MASTSearch
# Out:
# SearchResult containing 19 data products.
#
#  #       mission      year   author   exptime         target_name          distance
#                                          s                                  arcsec
# --- ----------------- ---- ---------- ------- ---------------------------- --------
#   0 Kepler Quarter 00 2009     Kepler    1800                kplr007375612      0.0
#   1 Kepler Quarter 01 2009     Kepler    1800                kplr007375612      0.0
#   2 Kepler Quarter 02 2009     Kepler    1800                kplr007375612      0.0
#   3 Kepler Quarter 03 2009     Kepler    1800                kplr007375612      0.0
#   4 Kepler Quarter 04 2010     Kepler    1800                kplr007375612      0.0
#   5 Kepler Quarter 05 2010     Kepler    1800                kplr007375612      0.0
#   6 Kepler Quarter 06 2010     Kepler    1800                kplr007375612      0.0
#   7 Kepler Quarter 07 2010     Kepler    1800                kplr007375612      0.0
#   8 Kepler Quarter 08 2011     Kepler    1800                kplr007375612      0.0
#   9 Kepler Quarter 09 2011     Kepler    1800                kplr007375612      0.0
#  10 Kepler Quarter 10 2011     Kepler    1800                kplr007375612      0.0
#  11 Kepler Quarter 11 2012     Kepler    1800                kplr007375612      0.0
#  12 Kepler Quarter 12 2012     Kepler    1800                kplr007375612      0.0
#  13 Kepler Quarter 13 2012     Kepler    1800                kplr007375612      0.0
#  14 Kepler Quarter 14 2012     Kepler    1800                kplr007375612      0.0
#  15 Kepler Quarter 15 2013     Kepler    1800                kplr007375612      0.0
#  16 Kepler Quarter 17 2013     Kepler    1800                kplr007375612      0.0
#  17 Kepler Quarter 16 2013     Kepler    1800                kplr007375612      0.0
#  18   Kepler Quarter  2009 KBONUS-BKG    1765 Gaia DR3 2078007608488503680      0.0

# %%
MASTSearch[-1] # Returns the last known result
# Out:
# SearchResult containing 1 data products.
#
#  #      mission     year   author   exptime         target_name          distance
#                                        s                                  arcsec
# --- --------------- ---- ---------- ------- ---------------------------- --------
#   0 Kepler Quarter  2009 KBONUS-BKG    1765 Gaia DR3 2078007608488503680      0.0

# %%
klc = MASTSearch[-1].download()
klc
# Out:
# <KeplerLightCurve length=65276 LABEL="KIC 7375612" AUTHOR=Kepler FLUX_ORIGIN=pdcsap_flux>
#        time               flux        ... sap_quality flatten_mask
#                       electron / s    ...
#        Time             float64       ...    int32       int32
# ------------------ ------------------ ... ----------- ------------
# 120.53880983125418 197246.93673447525 ...           0            0
# 120.55924434866756 195059.98276813613 ...           0            0
# 120.57967876642942 197781.34501513498 ...           0            0
# 120.60011338395998 199297.87596628862 ...           0            0
# 120.62054790137336 196840.14786505938 ...           0            0
# 120.64098231913522 195217.83576549654 ...           0            0
#  120.6614168365486 198059.59040782537 ...           0            0
# 120.68185145454481 199554.48771390945 ...           0            0
# 120.70228587184101 196556.32643857613 ...           0            0
#                ...                ... ...         ...          ...
# 1590.8375921230763                ——— ...           0            0
# 1590.8580264784396                ——— ...           0            0
# 1590.8784609343857                ——— ...           0            0
#  1590.898895490449                ——— ...           0            0
# 1590.9193298462778                ——— ...           0            0
#  1590.939764402341                ——— ...           0            0
# 1590.9601988587528                ——— ...           0            0
# 1590.9806332150474                ——— ...        8320         8320
# 1591.0010677715763                ——— ...           0            0

# %%
klc.filename
# Out:
# '/Users/wayfinder/.lightkurve/cache/mastDownload/HLSP/hlsp_kbonus-bkg_kepler_kepler_kic-007375612_kepler_v1.0/hlsp_kbonus-bkg_kepler_kepler_kic-007375612_kepler_v1.0_lc.fits'

# %%
klc.plot()
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %% [markdown]
# The above graph plots the lightcurve as observed by PDCSAP (Pre-search Data Conditioning Simple Aperture Photometry) Flux.
#
# The SAP (Simple Aperture Photometry) light curve is calculated by summing together the brightness of pixels that fall within an aperture set by the Kepler mission. This is often referred to as the optimal aperture, but in spite of its name can sometimes be improved upon! Because the SAP light curve is a sum of the brightness in chosen pixels, it is still subject to systematic artifacts of the mission.
#
# The PDCSAP light curve is subject to more treatment than the SAP light curve, and is specifically intended for detecting planets. The PDCSAP pipeline attempts to remove systematic artifacts while keeping planetary transits intact.
#
# Below is what both LCs look like with different flux processing.

# %%
ax = klc.plot(column='flux', label='PDCSAP Flux', normalize=True)
klc.plot(column='sap_flux', label='SAP Flux', normalize=True, ax=ax)
# Out:
# <Axes: xlabel='Time - 2454833 [BKJD days]', ylabel='Normalized sap_flux'>

# %% [markdown]
# Note: The converted datetime for day 2454833 in UTC is 2012-03-13 12:00:00.000.
