# %%
import pandas as pd
import matplotlib.pyplot as plt
from astroquery.mast import Mast, Observations
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive

# %%
keb = pd.read_csv(r'../data/kepler-eclipsing-binary-catalog.csv')
keb = keb.drop(columns='Unnamed: 11')
keb.columns
# Out:
# Index(['KIC', 'period', 'period_err', 'bjd0', 'bjd0_err', 'morph', 'GLon',
#        'GLat', 'kmag', 'Teff', 'SC'],
#       dtype='str')

# %%
keb.loc[5]
# Out:
# KIC                9472174
# period            0.125765
# period_err             0.0
# bjd0          54953.643178
# bjd0_err          0.018318
# morph                 0.78
# GLon               79.0187
# GLat               11.6745
# kmag                12.264
# Teff               10645.0
# SC                    True
# Name: 5, dtype: object

# %%
keplerObs = Observations.query_criteria(target_name='kplr011446443', obs_collection='Kepler')
keplerObs
# Out:
# <Table masked=True length=2>
# intentType obs_collection provenance_name ...  srcDen obsid  objID
#    str7         str6            str6      ... float64  str6   str6
# ---------- -------------- --------------- ... ------- ------ ------
#    science         Kepler          Kepler ...  5885.0 544538 771416
#    science         Kepler          Kepler ...  5885.0 601031 827909

# %%
keplerObs[1]['target_classification']
# Out:
# masked

# %%
keplerProds = Observations.get_product_list(keplerObs[1])

yourProd = Observations.filter_products(
                keplerProds, 
                # extension='kplr011446443-2009131110544_slc.fits', 
                mrp_only=False
            )
yourProd
