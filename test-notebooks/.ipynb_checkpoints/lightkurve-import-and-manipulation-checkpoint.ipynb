# %%
# %pip install lightkurve
# Out:
# Requirement already satisfied: lightkurve in /opt/anaconda3/lib/python3.13/site-packages (2.5.1)
# Requirement already satisfied: astropy>=5.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (7.1.1)
# Requirement already satisfied: astroquery>=0.3.10 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (0.4.11)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (4.13.5)
# Requirement already satisfied: bokeh>=2.3.2 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (3.8.0)
# Requirement already satisfied: fbpca>=1.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (1.0)
# Requirement already satisfied: matplotlib>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (3.10.6)
# Requirement already satisfied: memoization>=0.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (0.4.0)
# Requirement already satisfied: numpy>=1.26 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (2.3.5)
# Requirement already satisfied: pandas>=1.3.6 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (2.3.3)
# Requirement already satisfied: patsy>=0.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (1.0.1)
# Requirement already satisfied: requests>=2.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (2.32.5)
# Requirement already satisfied: s3fs>=2024.6.1 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (2025.10.0)
# Requirement already satisfied: scikit-learn>=0.24.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (1.7.2)
# Requirement already satisfied: scipy>=1.7 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (1.16.3)
# Requirement already satisfied: tqdm>=4.25.0 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (4.67.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (3.2.3)
# Requirement already satisfied: urllib3>=1.23 in /opt/anaconda3/lib/python3.13/site-packages (from lightkurve) (2.5.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from astropy>=5.0->lightkurve) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.9.29.0.35.48 in /opt/anaconda3/lib/python3.13/site-packages (from astropy>=5.0->lightkurve) (0.2025.11.10.0.38.31)
# Requirement already satisfied: PyYAML>=6.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from astropy>=5.0->lightkurve) (6.0.3)
# Requirement already satisfied: packaging>=22.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from astropy>=5.0->lightkurve) (25.0)
# Requirement already satisfied: html5lib>=0.999 in /opt/anaconda3/lib/python3.13/site-packages (from astroquery>=0.3.10->lightkurve) (1.1)
# Requirement already satisfied: keyring>=15.0 in /opt/anaconda3/lib/python3.13/site-packages (from astroquery>=0.3.10->lightkurve) (25.7.0)
# Requirement already satisfied: pyvo>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from astroquery>=0.3.10->lightkurve) (1.8.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from beautifulsoup4>=4.6.0->lightkurve) (4.15.0)
# Requirement already satisfied: Jinja2>=2.9 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh>=2.3.2->lightkurve) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh>=2.3.2->lightkurve) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh>=2.3.2->lightkurve) (2.7.0)
# Requirement already satisfied: pillow>=7.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh>=2.3.2->lightkurve) (12.0.0)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh>=2.3.2->lightkurve) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /opt/anaconda3/lib/python3.13/site-packages (from bokeh>=2.3.2->lightkurve) (2025.4.0)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (1.17.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.13/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from Jinja2>=2.9->bokeh>=2.3.2->lightkurve) (3.0.2)
# Requirement already satisfied: jaraco.classes in /opt/anaconda3/lib/python3.13/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/anaconda3/lib/python3.13/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve) (4.1.0)
# Requirement already satisfied: jaraco.context in /opt/anaconda3/lib/python3.13/site-packages (from keyring>=15.0->astroquery>=0.3.10->lightkurve) (0.0.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.1->lightkurve) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.1->lightkurve) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.1->lightkurve) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.1->lightkurve) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.1->lightkurve) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3.6->lightkurve) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.3.6->lightkurve) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.22.0->lightkurve) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.22.0->lightkurve) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.22.0->lightkurve) (2025.11.12)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/anaconda3/lib/python3.13/site-packages (from s3fs>=2024.6.1->lightkurve) (2.25.0)
# Requirement already satisfied: fsspec==2025.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from s3fs>=2024.6.1->lightkurve) (2025.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.13/site-packages (from s3fs>=2024.6.1->lightkurve) (3.13.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (0.12.0)
# Requirement already satisfied: botocore<1.40.50,>=1.40.46 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (1.40.46)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (6.7.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/anaconda3/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2024.6.1->lightkurve) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2024.6.1->lightkurve) (1.22.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn>=0.24.0->lightkurve) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn>=0.24.0->lightkurve) (3.5.0)
# Requirement already satisfied: more_itertools in /opt/anaconda3/lib/python3.13/site-packages (from jaraco.classes->keyring>=15.0->astroquery>=0.3.10->lightkurve) (10.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from lightkurve import search_targetpixelfile

# %matplotlib inline

pixelfile = search_targetpixelfile("KIC 8462852", quarter=16).download(quality_bitmask='hardest');
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/lightkurve/prf/__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
pixelfile.plot(frame=1000);

# %%
lc = pixelfile.to_lightcurve(aperture_mask='all');

# %%
lc.time, lc.flux

# %%
lc.plot()

# %%
pixelFile = search_targetpixelfile('KIC 6922244', quarter=4).download()

# %%
lc = pixelFile.to_lightcurve(aperture_mask=pixelFile.pipeline_mask)

# %%
lc.plot();

# %%
flat_lc = lc.flatten(window_length=401)
flat_lc.plot();

# %%
folded_lc = flat_lc.fold(period=3.522)
folded_lc.plot();

# %%
# binned_lc = folded_lc.bin(binsize=10)
# binned_lc.plot();

# %%
folded_lc.plot_river(bin_points=5, method='sigma')

# %%
lc.remove_nans().flatten(window_length=401).fold(period=3.5225).bin(binsize=10).plot();

# %%
import numpy as np
periodogram = flat_lc.to_periodogram(method="bls", period=np.arange(0.3, 10, 0.001))
periodogram.plot();

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.5f}'.format(best_fit_period))

# %%
tpf = search_targetpixelfile('EPIC 212593538', campaign=6).download()
lc = tpf.to_lightcurve(aperture_mask='all')
lc.plot();

# %%
from lightkurve import search_targetpixelfile
search_result = lk.search_targetpixelfile('Pi Mensae', mission='TESS', sector=1)
tpf = search_result.download(quality_bitmask='default')

# %%
tpf.mission
tpf.targetid

# %%
tpf.plot(aperture_mask=tpf.pipeline_mask);

# %%
lc = tpf.to_lightcurve()
lc.scatter();

# %%
aperture_mask = tpf.create_threshold_mask(threshold=10)
lc = tpf.to_lightcurve(aperture_mask=aperture_mask)
lc.scatter();

# %%
flat_lc = lc.flatten(window_length=1001)
flat_lc.errorbar();

# %%
mask = (flat_lc.time < 1346) | (flat_lc.time > 1350)
masked_lc = flat_lc[mask]
masked_lc.scatter(s=0.1);

# %%
clipped_lc = masked_lc.remove_outliers(sigma=6)
clipped_lc.scatter(s=0.1);

# %%
import numpy as np
periodogram = clipped_lc.to_periodogram(method="bls", period=np.arange(1, 10, 0.001))
periodogram.plot();

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.3f}'.format(best_fit_period))

# %%
folded_lc = clipped_lc.fold(period=6.300, t0=1325.504)
folded_lc.scatter(s=0.1);

# %%
binned_lc = folded_lc.bin(binsize=10) 
binned_lc.scatter();
