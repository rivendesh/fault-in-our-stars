# %% [markdown]
# # Building a 1-D CNN (Temporal Convolution Network) Classifier

# %% [markdown]
# ## 0. Imports and Config

# %%
# %load_ext autoreload
# %autoreload 2

import ast

import lightkurve as lk
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# from helpers import plotLightCurveFromDF, sampleRandomKIC, saveLightCurveFromDF
from sklearn.metrics import (accuracy_score, balanced_accuracy_score,
                             classification_report, confusion_matrix,
                             precision_recall_fscore_support)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from torch.utils.data import DataLoader, Dataset

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Set model training device. For Apple Silicon, the device is mps.

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

print(device)
# Out:
# mps

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Read and Preprocess Dataset

# %%
df = pd.read_parquet("/Users/tomlinn/Downloads/PREPROCESSED_FLUX_TCN_INPUT.parquet")
df
# Out:
#              KIC                                                  x  label
# 0         757450  [0.82121706, 0.8116605, 0.80877656, 0.7979615,...      0
# 1         892772  [0.7132433, 0.6999028, 0.6930329, 0.7038331, 0...      2
# 2        1026032  [1.1222867, 1.1136786, 1.1176132, 1.1167815, 1...      1
# 3        1026957  [1.258851, 1.248239, 1.246251, 1.2450396, 1.24...      0
# 4        1027438  [1.5406342, 1.5511838, 1.5508819, 1.5483795, 1...      2
# ...          ...                                                ...    ...
# 15599  202140012  [-2.2198217, -2.1861541, -2.1511917, -2.117524...      3
# 15600  202140013  [-1.8936313, -1.8610107, -1.8271353, -1.794514...      3
# 15601  202140059  [1.5995908, 1.5003388, 1.3972694, 1.2980174, 1...      2
# 15602  202140094  [1.6591667, 1.6754129, 1.6922839, 1.7085301, 1...      2
# 15603  202154314  [-2.572737, -2.4178846, -2.257076, -2.1022232,...      3
#
# [15604 rows x 3 columns]

# %%
df = df.reset_index()

# %% [markdown]
# ### 1.1. Schema

# %% [markdown]
# Rename features

# %%
renameMap = {
    'Class': 'class',
}

df = df.rename(columns=renameMap)
df
# Out:
#              KIC                                               time  \
# 0         757450  [131.51271468758932, 131.5331494016791, 131.55...
# 1         892772  [352.39657371611975, 352.43743948176416, 352.4...
# 2        1025986  [120.53931629149156, 120.55975094284076, 120.5...
# 3        1026032  [131.5127135392686, 131.53314824846893, 131.55...
# 4        1026957  [120.53930025400041, 120.55973490802717, 120.5...
# ...          ...                                                ...
# 18877  202140012  [1940.0083829938958, 1940.0288146129678, 1940....
# 18878  202140013  [1940.0083988461702, 1940.0288304660571, 1940....
# 18879  202140059  [1940.0088655664877, 1940.0292972054667, 1940....
# 18880  202140094  [1940.0088592208049, 1940.029290861763, 1940.0...
# 18881  202154314  [1940.0077134322783, 1940.028145020151, 1940.0...
#
#                                                     flux           class
# 0      [1.0392150925008297, 1.0383358659303283, 1.038...       CONFIRMED
# 1      [1.019566672226177, 1.0188446568700726, 1.0189...  FALSE POSITIVE
# 2      [1.0488531548750866, 1.0523113529281902, 1.051...       CANDIDATE
# 3      [1.0509398498643578, 1.0503349421979056, 1.050...  FALSE POSITIVE
# 4      [1.0599377280481261, 1.0591694377327983, 1.058...       CONFIRMED
# ...                                                  ...             ...
# 18877  [0.9961692094802856, 0.9965322613716125, 0.996...   VARIABLE STAR
# 18878  [0.9897362589836121, 0.9907680153846741, 0.991...   VARIABLE STAR
# 18879  [1.0229097604751587, 1.014359951019287, 1.0042...  FALSE POSITIVE
# 18880  [1.008090615272522, 1.0085946321487427, 1.0099...  FALSE POSITIVE
# 18881  [0.9968716502189636, 0.9981057643890381, 0.998...   VARIABLE STAR
#
# [18882 rows x 4 columns]

# %% [markdown]
# Remove duplicate KIC entries

# %%
def chooseLabel(labels):
    labels = list(labels)
    nonFp = [lab for lab in labels if lab != "FALSE POSITIVE"]

    if len(nonFp) > 0:
        # If there are multiple non-FP labels, take the most common one
        return pd.Series(nonFp).mode().iloc[0]

    # If all labels are FALSE POSITIVE, keep one of them
    return pd.Series(labels).mode().iloc[0]

# %%
df = (
    df.groupby("KIC", as_index=False)
        .agg({
            "time": "first",
            "flux": "first",
            "class": chooseLabel
        })
)

# %%
df['class'].value_counts()
# Out:
# class
# FALSE POSITIVE           7522
# ECLIPSING BINARY STAR    3049
# VARIABLE STAR            2980
# CONFIRMED                1972
# CANDIDATE                1637
# Name: count, dtype: int64

# %%
df.duplicated(subset="KIC").sum()
# Out:
# np.int64(0)

# %% [markdown]
# Remove 'CANDIDATE' class

# %%
df = df[df['class'] != 'CANDIDATE'].copy()

# %%
df
# Out:
#              KIC                                               time  \
# 0         757450  [131.51271468758932, 131.5331494016791, 131.55...
# 1         892772  [352.39657371611975, 352.43743948176416, 352.4...
# 3        1026032  [131.5127135392686, 131.53314824846893, 131.55...
# 4        1026957  [120.53930025400041, 120.55973490802717, 120.5...
# 5        1027438  [131.51268857505056, 131.53312328704487, 131.5...
# ...          ...                                                ...
# 17155  202140012  [1940.0083829938958, 1940.0288146129678, 1940....
# 17156  202140013  [1940.0083988461702, 1940.0288304660571, 1940....
# 17157  202140059  [1940.0088655664877, 1940.0292972054667, 1940....
# 17158  202140094  [1940.0088592208049, 1940.029290861763, 1940.0...
# 17159  202154314  [1940.0077134322783, 1940.028145020151, 1940.0...
#
#                                                     flux  \
# 0      [1.0392150925008297, 1.0383358659303283, 1.038...
# 1      [1.019566672226177, 1.0188446568700726, 1.0189...
# 3      [1.0509398498643578, 1.0503349421979056, 1.050...
# 4      [1.0599377280481261, 1.0591694377327983, 1.058...
# 5      [1.0649623994019086, 1.0653504391733866, 1.065...
# ...                                                  ...
# 17155  [0.9961692094802856, 0.9965322613716125, 0.996...
# 17156  [0.9897362589836121, 0.9907680153846741, 0.991...
# 17157  [1.0229097604751587, 1.014359951019287, 1.0042...
# 17158  [1.008090615272522, 1.0085946321487427, 1.0099...
# 17159  [0.9968716502189636, 0.9981057643890381, 0.998...
#
#                        class
# 0                  CONFIRMED
# 1             FALSE POSITIVE
# 3      ECLIPSING BINARY STAR
# 4                  CONFIRMED
# 5             FALSE POSITIVE
# ...                      ...
# 17155          VARIABLE STAR
# 17156          VARIABLE STAR
# 17157         FALSE POSITIVE
# 17158         FALSE POSITIVE
# 17159          VARIABLE STAR
#
# [15523 rows x 4 columns]

# %% [markdown]
# Encode labels

# %%
def encodeLabels(df):
    """
    Function to encode the labels in the 'Class' feature of a given dataframe df.
    """
    le = LabelEncoder()
    y = le.fit_transform(df["class"].values)
    df = df.copy()
    df["label"] = y

    return df, le

# %%
df, le = encodeLabels(df)
df
# Out:
#              KIC                                               time  \
# 0         757450  [131.51271468758932, 131.5331494016791, 131.55...
# 1         892772  [352.39657371611975, 352.43743948176416, 352.4...
# 3        1026032  [131.5127135392686, 131.53314824846893, 131.55...
# 4        1026957  [120.53930025400041, 120.55973490802717, 120.5...
# 5        1027438  [131.51268857505056, 131.53312328704487, 131.5...
# ...          ...                                                ...
# 17155  202140012  [1940.0083829938958, 1940.0288146129678, 1940....
# 17156  202140013  [1940.0083988461702, 1940.0288304660571, 1940....
# 17157  202140059  [1940.0088655664877, 1940.0292972054667, 1940....
# 17158  202140094  [1940.0088592208049, 1940.029290861763, 1940.0...
# 17159  202154314  [1940.0077134322783, 1940.028145020151, 1940.0...
#
#                                                     flux  \
# 0      [1.0392150925008297, 1.0383358659303283, 1.038...
# 1      [1.019566672226177, 1.0188446568700726, 1.0189...
# 3      [1.0509398498643578, 1.0503349421979056, 1.050...
# 4      [1.0599377280481261, 1.0591694377327983, 1.058...
# 5      [1.0649623994019086, 1.0653504391733866, 1.065...
# ...                                                  ...
# 17155  [0.9961692094802856, 0.9965322613716125, 0.996...
# 17156  [0.9897362589836121, 0.9907680153846741, 0.991...
# 17157  [1.0229097604751587, 1.014359951019287, 1.0042...
# 17158  [1.008090615272522, 1.0085946321487427, 1.0099...
# 17159  [0.9968716502189636, 0.9981057643890381, 0.998...
#
#                        class  label
# 0                  CONFIRMED      0
# 1             FALSE POSITIVE      2
# 3      ECLIPSING BINARY STAR      1
# 4                  CONFIRMED      0
# 5             FALSE POSITIVE      2
# ...                      ...    ...
# 17155          VARIABLE STAR      3
# 17156          VARIABLE STAR      3
# 17157         FALSE POSITIVE      2
# 17158         FALSE POSITIVE      2
# 17159          VARIABLE STAR      3
#
# [15523 rows x 5 columns]

# %% [markdown]
# ### 1.2. Light curve raw data preprocessing

# %%
def to_1d_float_array(x):
    if isinstance(x, str):
        x = ast.literal_eval(x)
    return np.asarray(x, dtype=np.float32).reshape(-1)


def clean_time_flux(time, flux):
    time = to_1d_float_array(time)
    flux = to_1d_float_array(flux)

    if len(time) == 0 or len(flux) == 0:
        return None, None

    n = min(len(time), len(flux))
    time = time[:n]
    flux = flux[:n]

    mask = np.isfinite(time) & np.isfinite(flux)
    time = time[mask]
    flux = flux[mask]

    if len(time) < 2:
        return None, None

    return time, flux


def normalize_flux(flux):
    flux = np.asarray(flux, dtype=np.float32)

    if len(flux) == 0:
        return None

    med = np.median(flux)
    if not np.isfinite(med) or med == 0:
        med = 1.0

    return flux / med - 1.0


def clip_flux(flux, clip_sigma=5.0):
    mu = np.mean(flux)
    sd = np.std(flux)

    if np.isfinite(sd) and sd > 0:
        lo, hi = mu - clip_sigma * sd, mu + clip_sigma * sd
        return np.clip(flux, lo, hi)

    return flux


def resample_to_fixed_length(time, flux, seq_len=2000):
    if len(time) < 2:
        return None

    order = np.argsort(time)
    time = time[order]
    flux = flux[order]

    uniq_time, uniq_idx = np.unique(time, return_index=True)
    time = uniq_time
    flux = flux[uniq_idx]

    if len(time) < 2:
        return None

    t_new = np.linspace(time.min(), time.max(), seq_len)
    y_new = np.interp(t_new, time, flux).astype(np.float32)

    return y_new


def standardize_flux(flux):
    x = flux - np.mean(flux)
    std = np.std(x)

    if np.isfinite(std) and std > 0:
        x = x / std

    return x


def preprocess_light_curve(time, flux, seq_len=2000):
    time, flux = clean_time_flux(time, flux)
    if time is None:
        return None

    flux = normalize_flux(flux)
    if flux is None:
        return None

    flux = clip_flux(flux)

    x = resample_to_fixed_length(time, flux, seq_len)
    if x is None:
        return None

    x = standardize_flux(x)

    return x.astype(np.float32)

# %%
def preprocess_dataframe(df, seq_len=2000):
    processed_rows = []
    
    for _, row in df.iterrows():
        x = preprocess_light_curve(row["time"], row["flux"], seq_len=seq_len)

        if x is None:
            continue  # skip bad rows

        appendDict = {
            "KIC": row["KIC"],
            "x": x,
            "label": row["label"],
            "class": row['class']
        }

        processed_rows.append(appendDict)

    return pd.DataFrame(processed_rows)

# %% [markdown]
# #### 1.2.1 Process with SEQ_LEN

# %%
SEQ_LEN = 20_000
df = preprocess_dataframe(df, seq_len=SEQ_LEN)

# %%
x = df.iloc[0]['x']
x
# Out:
# array([0.8211676 , 0.8061057 , 0.81160194, ..., 0.729084  , 0.73050064,
#        0.72755677], shape=(20000,), dtype=float32)

# %%
df.to_parquet(r"./local-assets/PREPROCESSED_FLUX_TCN_INPUT.parquet")
del df

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Modeling

# %%
df = pd.read_parquet(r"./local-assets/PREPROCESSED_FLUX_TCN_INPUT.parquet")
df
# Out:
#              KIC                                                  x  label  \
# 0         757450  [0.8211676, 0.8061057, 0.81160194, 0.8019038, ...      0
# 1         892772  [0.71329564, 0.7053239, 0.6999545, 0.72388095,...      2
# 2        1026032  [1.1223013, 1.0959345, 1.113703, 1.1105226, 1....      1
# 3        1026957  [1.2589424, 1.2489272, 1.2483299, 1.2483612, 1...      0
# 4        1027438  [1.5407294, 1.5469184, 1.5512859, 1.5463995, 1...      2
# ...          ...                                                ...    ...
# 15516  202140012  [-2.2199585, -2.203124, -2.1862893, -2.1681597...      3
# 15517  202140013  [-1.8936684, -1.8773583, -1.8610481, -1.843483...      3
# 15518  202140059  [1.5995309, 1.5499053, 1.5002797, 1.4468366, 1...      2
# 15519  202140094  [1.6591288, 1.6672517, 1.6753746, 1.6841224, 1...      2
# 15520  202154314  [-2.5730886, -2.4956522, -2.4182158, -2.334822...      3
#
#                        class
# 0                  CONFIRMED
# 1             FALSE POSITIVE
# 2      ECLIPSING BINARY STAR
# 3                  CONFIRMED
# 4             FALSE POSITIVE
# ...                      ...
# 15516          VARIABLE STAR
# 15517          VARIABLE STAR
# 15518         FALSE POSITIVE
# 15519         FALSE POSITIVE
# 15520          VARIABLE STAR
#
# [15521 rows x 4 columns]

# %%
df['label'].value_counts().sort_index()
# Out:
# label
# 0    1972
# 1    3049
# 2    7520
# 3    2980
# Name: count, dtype: int64

# %% [markdown]
# Experiment with weighted-class loss.

# %%
# classes = np.unique(df["label"])
# weights = compute_class_weight(
#     class_weight="balanced",
#     classes=classes,
#     y=df["label"].values
# )

# classWeights = torch.tensor(weights, dtype=torch.float32)
# print(classWeights)

# %% [markdown]
# ### 2.1. Building Dataset as Tensors

# %%
class LightCurveDataset(Dataset):
    def __init__(self, df):
        self.x = df["x"].values
        self.y = df["label"].values

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x = torch.tensor(self.x[idx], dtype=torch.float32)  # (seq_len,)
        x = x.unsqueeze(0)  # (1, seq_len)
        y = torch.tensor(self.y[idx], dtype=torch.long)
        return x, y

# %% [markdown]
# ### 2.2. DataLoaders and Train/Test/Val Splitting

# %%
train_df, temp_df = train_test_split(
    df,
    test_size=0.3,
    stratify=df["label"],
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    stratify=temp_df["label"],
    random_state=42
)

train_ds = LightCurveDataset(train_df)
val_ds = LightCurveDataset(val_df)
test_ds = LightCurveDataset(test_df)

BATCH_SIZE = 64

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# ### 2.3. Class-weighted loss

# %%
classes = np.unique(train_df["label"])
weights = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=train_df["label"].values
)

class_weights = torch.tensor(weights, dtype=torch.float32)

print(f"Class weights:\n{class_weights}")
# Out:
# Class weights:
# tensor([1.9681, 1.2727, 0.5160, 1.3020])

# %% [markdown]
# ### 2.4. TCN Block and Model

# %%
class TCNBlock(nn.Module):
    def __init__(self, in_ch, out_ch, kernel_size=5, dilation=1):
        super().__init__()
        padding = (kernel_size - 1) * dilation // 2

        self.conv = nn.Conv1d(
            in_ch, 
            out_ch, 
            kernel_size,
            padding=padding, 
            dilation=dilation
        )
        self.bn = nn.BatchNorm1d(out_ch)

        self.residual = nn.Conv1d(in_ch, out_ch, 1) if in_ch != out_ch else nn.Identity()

    def forward(self, x):
        out = F.relu(self.bn(self.conv(x)))
        return out + self.residual(x)


class TCN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()

        self.block1 = TCNBlock(1, 32, dilation=1)
        self.block2 = TCNBlock(32, 64, dilation=2)
        self.block3 = TCNBlock(64, 128, dilation=4)
        # self.block4 = TCNBlock(128, 256, dilation=8)

        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(128, num_classes)

    def forward(self, x):
        # x: (B, 1, T)
        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)
        # x = self.block4(x)

        x = self.pool(x).squeeze(-1)  # (B, 128)
        return self.fc(x)

# %% [markdown]
# ### 2.5. Training

# %% [markdown]
# Training setup.

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

model = TCN(num_classes=len(classes)).to(device)

criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# Training loop.

# %%
def train(model, train_loader, val_loader, epochs=10):
    for epoch in range(epochs):
        model.train()
        train_loss = 0

        for x, y in train_loader:
            x = x.to(device)
            y = y.to(device)

            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        # Validation
        model.eval()
        correct = 0
        total = 0

        with torch.no_grad():
            for x, y in val_loader:
                x = x.to(device)
                y = y.to(device)

                logits = model(x)
                preds = logits.argmax(dim=1)

                correct += (preds == y).sum().item()
                total += y.size(0)

        print(f"Epoch {epoch+1} | Loss: {train_loss:.3f} | Val Acc: {correct/total:.3f}")

# %% [markdown]
# Run training.

# %%
# %%time
EPOCHS = 100
train(model, train_loader, val_loader, epochs=EPOCHS)
# Out:
# Epoch 1 | Loss: 195.791 | Val Acc: 0.399
# Epoch 2 | Loss: 176.083 | Val Acc: 0.405
# Epoch 3 | Loss: 164.253 | Val Acc: 0.427
# Epoch 4 | Loss: 157.102 | Val Acc: 0.461
# Epoch 5 | Loss: 151.888 | Val Acc: 0.439
# Epoch 6 | Loss: 149.477 | Val Acc: 0.476
# Epoch 7 | Loss: 147.370 | Val Acc: 0.445
# Epoch 8 | Loss: 145.186 | Val Acc: 0.459
# Epoch 9 | Loss: 143.502 | Val Acc: 0.459
# Epoch 10 | Loss: 142.560 | Val Acc: 0.446
# Epoch 11 | Loss: 140.930 | Val Acc: 0.508
# Epoch 12 | Loss: 139.854 | Val Acc: 0.549
# Epoch 13 | Loss: 139.225 | Val Acc: 0.525
# Epoch 14 | Loss: 137.001 | Val Acc: 0.463
# Epoch 15 | Loss: 136.975 | Val Acc: 0.542
# Epoch 16 | Loss: 135.794 | Val Acc: 0.496
# Epoch 17 | Loss: 134.202 | Val Acc: 0.532
# Epoch 18 | Loss: 134.528 | Val Acc: 0.570
# Epoch 19 | Loss: 133.348 | Val Acc: 0.493
# Epoch 20 | Loss: 132.013 | Val Acc: 0.569
# Epoch 21 | Loss: 130.399 | Val Acc: 0.533
# Epoch 22 | Loss: 129.660 | Val Acc: 0.449
# Epoch 23 | Loss: 129.360 | Val Acc: 0.596
# Epoch 24 | Loss: 129.027 | Val Acc: 0.586
# Epoch 25 | Loss: 128.041 | Val Acc: 0.553
# Epoch 26 | Loss: 127.065 | Val Acc: 0.622
# Epoch 27 | Loss: 126.165 | Val Acc: 0.564
# Epoch 28 | Loss: 126.287 | Val Acc: 0.611
# Epoch 29 | Loss: 124.808 | Val Acc: 0.470
# Epoch 30 | Loss: 124.591 | Val Acc: 0.601
# Epoch 31 | Loss: 125.487 | Val Acc: 0.598
# Epoch 32 | Loss: 123.559 | Val Acc: 0.513
# Epoch 33 | Loss: 124.066 | Val Acc: 0.549
# Epoch 34 | Loss: 122.353 | Val Acc: 0.570
# Epoch 35 | Loss: 123.042 | Val Acc: 0.625
# Epoch 36 | Loss: 123.504 | Val Acc: 0.580
# Epoch 37 | Loss: 121.899 | Val Acc: 0.625
# Epoch 38 | Loss: 121.774 | Val Acc: 0.617
# Epoch 39 | Loss: 122.637 | Val Acc: 0.601
# Epoch 40 | Loss: 121.827 | Val Acc: 0.591
# Epoch 41 | Loss: 121.610 | Val Acc: 0.590
# Epoch 42 | Loss: 121.743 | Val Acc: 0.600
# Epoch 43 | Loss: 119.681 | Val Acc: 0.538
# Epoch 44 | Loss: 118.412 | Val Acc: 0.601
# Epoch 45 | Loss: 119.677 | Val Acc: 0.599
# Epoch 46 | Loss: 119.238 | Val Acc: 0.623
# Epoch 47 | Loss: 118.856 | Val Acc: 0.567
# Epoch 48 | Loss: 118.220 | Val Acc: 0.606
# Epoch 49 | Loss: 117.792 | Val Acc: 0.623
# Epoch 50 | Loss: 118.318 | Val Acc: 0.530
# Epoch 51 | Loss: 119.923 | Val Acc: 0.565
# Epoch 52 | Loss: 118.002 | Val Acc: 0.614
# Epoch 53 | Loss: 117.895 | Val Acc: 0.547
# Epoch 54 | Loss: 118.288 | Val Acc: 0.623
# Epoch 55 | Loss: 117.546 | Val Acc: 0.549
# Epoch 56 | Loss: 117.556 | Val Acc: 0.600
# Epoch 57 | Loss: 116.431 | Val Acc: 0.636
# Epoch 58 | Loss: 115.823 | Val Acc: 0.588
# Epoch 59 | Loss: 116.965 | Val Acc: 0.576
# Epoch 60 | Loss: 116.593 | Val Acc: 0.621
# Epoch 61 | Loss: 115.812 | Val Acc: 0.521
# Epoch 62 | Loss: 116.110 | Val Acc: 0.609
# Epoch 63 | Loss: 116.637 | Val Acc: 0.622
# Epoch 64 | Loss: 115.354 | Val Acc: 0.586
# Epoch 65 | Loss: 116.268 | Val Acc: 0.604
# Epoch 66 | Loss: 115.312 | Val Acc: 0.600
# Epoch 67 | Loss: 115.964 | Val Acc: 0.568
# Epoch 68 | Loss: 114.205 | Val Acc: 0.395
# Epoch 69 | Loss: 115.112 | Val Acc: 0.561
# Epoch 70 | Loss: 114.623 | Val Acc: 0.619
# Epoch 71 | Loss: 114.796 | Val Acc: 0.604
# Epoch 72 | Loss: 114.470 | Val Acc: 0.612
# Epoch 73 | Loss: 115.438 | Val Acc: 0.577
# Epoch 74 | Loss: 114.013 | Val Acc: 0.628
# Epoch 75 | Loss: 114.891 | Val Acc: 0.636
# Epoch 76 | Loss: 114.408 | Val Acc: 0.599
# Epoch 77 | Loss: 114.056 | Val Acc: 0.607
# Epoch 78 | Loss: 114.255 | Val Acc: 0.623
# Epoch 79 | Loss: 113.525 | Val Acc: 0.613
# Epoch 80 | Loss: 114.266 | Val Acc: 0.592
# Epoch 81 | Loss: 113.420 | Val Acc: 0.615
# Epoch 82 | Loss: 113.132 | Val Acc: 0.531
# Epoch 83 | Loss: 114.127 | Val Acc: 0.637
# Epoch 84 | Loss: 112.733 | Val Acc: 0.619
# Epoch 85 | Loss: 112.938 | Val Acc: 0.615
# Epoch 86 | Loss: 114.602 | Val Acc: 0.619
# Epoch 87 | Loss: 112.041 | Val Acc: 0.614
# Epoch 88 | Loss: 113.678 | Val Acc: 0.568
# Epoch 89 | Loss: 113.158 | Val Acc: 0.638
# Epoch 90 | Loss: 112.234 | Val Acc: 0.600
# Epoch 91 | Loss: 114.340 | Val Acc: 0.608
# Epoch 92 | Loss: 113.946 | Val Acc: 0.633
# Epoch 93 | Loss: 111.849 | Val Acc: 0.639
# Epoch 94 | Loss: 112.897 | Val Acc: 0.633
# Epoch 95 | Loss: 111.376 | Val Acc: 0.568
# Epoch 96 | Loss: 112.707 | Val Acc: 0.624
# Epoch 97 | Loss: 113.053 | Val Acc: 0.563
# Epoch 98 | Loss: 111.606 | Val Acc: 0.631
# Epoch 99 | Loss: 113.117 | Val Acc: 0.573
# Epoch 100 | Loss: 111.979 | Val Acc: 0.607
# CPU times: user 2min 1s, sys: 42.6 s, total: 2min 44s
# Wall time: 1h 13min 23s

# %%
torch.save(model.state_dict(), "./local-assets/TCN-model.pt")

# %% [markdown]
# ### 2.6. Eval

# %%
def runInference(model, test_loader):
    model.eval()

    all_preds = []
    all_labels = []

    with torch.no_grad():
        for x, y in test_loader:
            x = x.to(device)

            logits = model(x)
            preds = logits.argmax(dim=1).cpu()

            all_preds.extend(preds.numpy())
            all_labels.extend(y.numpy())

    return all_preds, all_labels

# %%
labelToClass = (
    df[["label", "class"]]
    .drop_duplicates()
    .sort_values("label")
    .set_index("label")["class"]
    .to_dict()
)

classNames = [labelToClass[i] for i in sorted(labelToClass.keys())]

print(labelToClass)
# Out:
# {0: 'CONFIRMED', 1: 'ECLIPSING BINARY STAR', 2: 'FALSE POSITIVE', 3: 'VARIABLE STAR'}

# %%
y_pred, y_true = runInference(model, test_loader)
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# %%
class_names = [labelToClass[i] for i in sorted(labelToClass.keys())]

# %% [markdown]
# #### 2.6.1 Overall Metrics

# %%
print("Overall metrics:")
print(f"Accuracy:            {accuracy_score(y_true, y_pred):.4f}")
print(f"Balanced accuracy:   {balanced_accuracy_score(y_true, y_pred):.4f}")

p_macro, r_macro, f1_macro, _ = precision_recall_fscore_support(
    y_true, 
    y_pred, 
    average="macro", 
    zero_division=0
)
p_weighted, r_weighted, f1_weighted, _ = precision_recall_fscore_support(
    y_true, 
    y_pred, 
    average="weighted", 
    zero_division=0
)

print(f"Macro precision:      {p_macro:.4f}")
print(f"Macro recall:         {r_macro:.4f}")
print(f"Macro F1:             {f1_macro:.4f}")
print(f"Weighted precision:   {p_weighted:.4f}")
print(f"Weighted recall:      {r_weighted:.4f}")
print(f"Weighted F1:          {f1_weighted:.4f}")

print("\nPer-class report:")
report = classification_report(
    y_true,
    y_pred,
    target_names=classNames,
    digits=4,
    zero_division=0
)
print(report)
# Out:
# Overall metrics:
# Accuracy:            0.6065
# Balanced accuracy:   0.7171
# Macro precision:      0.6549
# Macro recall:         0.7171
# Macro F1:             0.6302
# Weighted precision:   0.7148
# Weighted recall:      0.6065
# Weighted F1:          0.6047
#
# Per-class report:
#                        precision    recall  f1-score   support
#
#             CONFIRMED     0.3728    0.9257    0.5315       296
# ECLIPSING BINARY STAR     0.9176    0.7549    0.8283       457
#        FALSE POSITIVE     0.7934    0.3848    0.5182      1128
#         VARIABLE STAR     0.5358    0.8031    0.6428       447
#
#              accuracy                         0.6065      2328
#             macro avg     0.6549    0.7171    0.6302      2328
#          weighted avg     0.7148    0.6065    0.6047      2328

# %% [markdown]
# #### 2.6.2 Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred)

cm_df = pd.DataFrame(cm, index=[f"True {c}" for c in class_names], columns=[f"Pred {c}" for c in class_names])
print("Confusion matrix:")
display(cm_df)

plt.figure(figsize=(12, 8))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()
# Out:
# Confusion matrix:
#                             Pred CONFIRMED  Pred ECLIPSING BINARY STAR  \
# True CONFIRMED                         274                           7
# True ECLIPSING BINARY STAR              66                         345
# True FALSE POSITIVE                    392                          19
# True VARIABLE STAR                       3                           5
#
#                             Pred FALSE POSITIVE  Pred VARIABLE STAR
# True CONFIRMED                                9                   6
# True ECLIPSING BINARY STAR                   24                  22
# True FALSE POSITIVE                         434                 283
# True VARIABLE STAR                           80                 359

# %% [markdown]
# #### 2.6.3 Misclassification Summary

# %%
# Misclassification summary
mis_mask = y_true != y_pred
mis_df = pd.DataFrame({
    "true": y_true[mis_mask],
    "pred": y_pred[mis_mask]
})

print("Misclassification summary:")
if len(mis_df) == 0:
    print("No misclassifications.")
else:
    mis_df["pair"] = list(zip(mis_df["true"], mis_df["pred"]))
    pair_counts = mis_df["pair"].value_counts()

    pretty_pairs = []
    for (t, p), n in pair_counts.items():
        pretty_pairs.append({
            "true": class_names[int(t)] if int(t) < len(class_names) else str(t),
            "pred": class_names[int(p)] if int(p) < len(class_names) else str(p),
            "count": int(n)
        })

    display(pd.DataFrame(pretty_pairs))
# Out:
# Misclassification summary:
#                      true                   pred  count
# 0          FALSE POSITIVE              CONFIRMED    392
# 1          FALSE POSITIVE          VARIABLE STAR    283
# 2           VARIABLE STAR         FALSE POSITIVE     80
# 3   ECLIPSING BINARY STAR              CONFIRMED     66
# 4   ECLIPSING BINARY STAR         FALSE POSITIVE     24
# 5   ECLIPSING BINARY STAR          VARIABLE STAR     22
# 6          FALSE POSITIVE  ECLIPSING BINARY STAR     19
# 7               CONFIRMED         FALSE POSITIVE      9
# 8               CONFIRMED  ECLIPSING BINARY STAR      7
# 9               CONFIRMED          VARIABLE STAR      6
# 10          VARIABLE STAR  ECLIPSING BINARY STAR      5
# 11          VARIABLE STAR              CONFIRMED      3
