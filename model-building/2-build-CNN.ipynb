# %%
# %load_ext autoreload
# %autoreload 2

from helpers import plotLightCurveFromDF, saveLightCurveFromDF, sampleRandomKIC
import lightkurve as lk
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gc

# %matplotlib inline
# Out:
# /Users/wayfinder/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/lightkurve/prf/__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
# %%time
df = pd.read_parquet("./local-assets/MERGED_LCS.parquet")
df
# Out:
# CPU times: user 5.14 s, sys: 12 s, total: 17.1 s
# Wall time: 15 s
#                                                         time  \
# KIC
# 757450     [131.51271468758932, 131.5331494016791, 131.55...
# 892772     [352.39657371611975, 352.43743948176416, 352.4...
# 1025986    [120.53931629149156, 120.55975094284076, 120.5...
# 1026032    [131.5127135392686, 131.53314824846893, 131.55...
# 1026957    [120.53930025400041, 120.55973490802717, 120.5...
# ...                                                      ...
# 202140012  [1940.0083829938958, 1940.0288146129678, 1940....
# 202140013  [1940.0083988461702, 1940.0288304660571, 1940....
# 202140059  [1940.0088655664877, 1940.0292972054667, 1940....
# 202140094  [1940.0088592208049, 1940.029290861763, 1940.0...
# 202154314  [1940.0077134322783, 1940.028145020151, 1940.0...
#
#                                                         flux           Class
# KIC
# 757450     [1.0392150925008297, 1.0383358659303283, 1.038...       CONFIRMED
# 892772     [1.019566672226177, 1.0188446568700726, 1.0189...  FALSE POSITIVE
# 1025986    [1.0488531548750866, 1.0523113529281902, 1.051...       CANDIDATE
# 1026032    [1.0509398498643578, 1.0503349421979056, 1.050...  FALSE POSITIVE
# 1026957    [1.0599377280481261, 1.0591694377327983, 1.058...       CONFIRMED
# ...                                                      ...             ...
# 202140012  [0.9961692094802856, 0.9965322613716125, 0.996...   VARIABLE STAR
# 202140013  [0.9897362589836121, 0.9907680153846741, 0.991...   VARIABLE STAR
# 202140059  [1.0229097604751587, 1.014359951019287, 1.0042...  FALSE POSITIVE
# 202140094  [1.008090615272522, 1.0085946321487427, 1.0099...  FALSE POSITIVE
# 202154314  [0.9968716502189636, 0.9981057643890381, 0.998...   VARIABLE STAR
#
# [18882 rows x 3 columns]

# %%
df['Class'].value_counts()
# Out:
# Class
# FALSE POSITIVE           9079
# ECLIPSING BINARY STAR    3212
# VARIABLE STAR            2980
# CONFIRMED                1973
# CANDIDATE                1638
# Name: count, dtype: int64

# %%
kic = sampleRandomKIC(df)
plotLightCurveFromDF(df, kic)

# %%
kic
# Out:
# np.int64(8330207)

# %%
df.loc[kic]
# Out:
# time     [539.4700321007331, 539.49046646442, 539.51090...
# flux     [0.9738226712674939, 0.9739697378448765, 0.974...
# Class                                            CANDIDATE
# Name: 8330207, dtype: object

# %% [markdown]
# ---

# %%
kic = 7898576
plotLightCurveFromDF(df, kic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only 0-dimensional arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 kic = 7898576
# ----> 2 plotLightCurveFromDF(df, kic)
#
# File ~/Code/fault-in-our-stars/model-building/helpers.py:36, in plotLightCurveFromDF(df, kic, with_error)
#      34     plt.errorbar(t, f, yerr=e, fmt='-', linewidth=1)
#      35 else:
# ---> 36     plt.plot(t, f, linewidth=1)
#      38 plt.xlabel("Time")
#      39 plt.ylabel(r"Normalized Flux (e$^{-}$ s$^{-1}$)")
#
# File ~/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/matplotlib/pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File ~/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
# -> 1779     self.add_line(line)
#    1780 if scalex:
#    1781     self._request_autoscale_view("x")
#
# File ~/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/matplotlib/axes/_base.py:2417, in _AxesBase.add_line(self, line)
#    2414 if line.get_clip_path() is None:
#    2415     line.set_clip_path(self.patch)
# -> 2417 self._update_line_limits(line)
#    2418 if not line.get_label():
#    2419     line.set_label(f'_child{len(self._children)}')
#
# File ~/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/matplotlib/axes/_base.py:2440, in _AxesBase._update_line_limits(self, line)
#    2436 def _update_line_limits(self, line):
#    2437     """
#    2438     Figures out the data limit of the given line, updating `.Axes.dataLim`.
#    2439     """
# -> 2440     path = line.get_path()
#    2441     if path.vertices.size == 0:
#    2442         return
#
# File ~/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/matplotlib/lines.py:1052, in Line2D.get_path(self)
#    1050 """Return the `~matplotlib.path.Path` associated with this line."""
#    1051 if self._invalidy or self._invalidx:
# -> 1052     self.recache()
#    1053 return self._path
#
# File ~/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/matplotlib/lines.py:689, in Line2D.recache(self, always)
#     687 if always or self._invalidx:
#     688     xconv = self.convert_xunits(self._xorig)
# --> 689     x = _to_unmasked_float_array(xconv).ravel()
#     690 else:
#     691     x = self._x
#
# File ~/Code/fault-in-our-stars/.env/lib/python3.13/site-packages/matplotlib/cbook.py:1355, in _to_unmasked_float_array(x)
#    1353     return np.ma.asarray(x, float).filled(np.nan)
#    1354 else:
# -> 1355     return np.asarray(x, float)
#
# ValueError: setting an array element with a sequence.
